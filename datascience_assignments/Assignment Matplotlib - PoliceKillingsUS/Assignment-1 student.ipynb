# %% [markdown]
# # WITH PANDAS AND MATPLOTLIB

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
#
# 1. Number of people by gender
# 1. Kill weapon
# 1. Age of killed people
# 1. Race of killed people
# 1. Killed People According to Races (Pie Chart)
# 1. Most common 15 Name or Surname of killed people
#
# <br>

# %% [markdown]
# read data
#
# if didn't work you can use this parameters: encoding="windows-1252"

# %%
kill= pd.read_csv('https://raw.githubusercontent.com/RegaipKURT/Data_Visualisation/master/PoliceKillingsUS.csv', encoding="windows-1252")
kill
# Out:
#         id                name      date   manner_of_death       armed   age  \
# 0        3          Tim Elliot  02/01/15              shot         gun  53.0
# 1        4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2        5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3        8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4        9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
# ...    ...                 ...       ...               ...         ...   ...
# 2530  2822    Rodney E. Jacobs  28/07/17              shot         gun  31.0
# 2531  2813               TK TK  28/07/17              shot     vehicle   NaN
# 2532  2818  Dennis W. Robinson  29/07/17              shot         gun  48.0
# 2533  2817       Isaiah Tucker  31/07/17              shot     vehicle  28.0
# 2534  2815        Dwayne Jeune  31/07/17              shot       knife  32.0
#
# ...

# %% [markdown]
# ## 1: Plot number of people by gender

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
gender= kill.groupby("gender").sum().index
gender
# Out:
# Index(['F', 'M'], dtype='object', name='gender')

# %%
fig, ax= plt.subplots()
ax.bar(gender, kills)
fig.suptitle('Gender Distribution')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17400/464001051.py in <module>
#       1 fig, ax= plt.subplots()
# ----> 2 ax.bar(gender, kills)
#       3 fig.suptitle('Gender Distribution')
#       4 plt.show()
#
# NameError: name 'kills' is not defined

# %% [markdown]
# ## 2: Plot 7 most common kill weapons

# %%
kill["armed"].value_counts().head(7)
# Out:
# gun             1398
# knife            373
# vehicle          177
# unarmed          171
# undetermined     117
# toy weapon       104
# machete           18
# Name: armed, dtype: int64

# %%
armed= kill.groupby("armed").sum().index
armed
# Out:
# Index(['Taser', 'air conditioner', 'ax', 'baseball bat',
#        'baseball bat and bottle', 'baseball bat and fireplace poker', 'baton',
#        'bayonet', 'bean-bag gun', 'beer bottle', 'blunt object', 'box cutter',
#        'brick', 'carjack', 'chain', 'chain saw', 'contractor's level',
#        'cordless drill', 'crossbow', 'crowbar', 'fireworks', 'flagpole',
#        'flashlight', 'garden tool', 'glass shard', 'gun', 'gun and knife',
#        'guns and explosives', 'hammer', 'hand torch', 'hatchet',
#        'hatchet and gun', 'knife', 'lawn mower blade', 'machete',
#        'machete and gun', 'meat cleaver', 'metal hand tool', 'metal object',
#        'metal pipe', 'metal pole', 'metal rake', 'metal stick', 'motorcycle',
#        'nail gun', 'oar', 'pen', 'pick-axe', 'piece of wood', 'pipe',
#        'pitchfork', 'pole', 'pole and knife', 'rock', 'scissors',
#        'screwdriver', 'sharp object', 'shovel', 'spear', 'stapler',
# ...

# %%
# with matplotlib
fig, ax= plt.subplots()
ax.bar(armed[25], kills)
#ax.bar(armed[25],armed[32],armed[64],armed[25],armed[65],armed[63],armed[66], kills)
fig.suptitle('Gender Distribution')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17400/1800624018.py in <module>
#       1 # with matplotlib
#       2 fig, ax= plt.subplots()
# ----> 3 ax.bar(armed[25], kills)
#       4 #ax.bar(armed[25],armed[32],armed[64],armed[25],armed[65],armed[63],armed[66], kills)
#       5 fig.suptitle('Gender Distribution')
#
# NameError: name 'kills' is not defined

# %% [markdown]
# ## 3: Plot number of age of killed people under two groups : Under 25 and Above 25

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill["age_cat"]= column value kill["age"]
kill.head()
# Out:
#   File "C:\Users\LENOVO\AppData\Local\Temp/ipykernel_17400/2077033996.py", line 1
#     kill["age_cat"]= column value kill["age"]
#                             ^
# SyntaxError: invalid syntax

# %%
kill.loc[kill.age>25,'age_cat']='above25'
kill.loc[kill.age<25,'age_cat']='below25'
kill
# Out:
#         id                name      date   manner_of_death       armed   age  \
# 0        3          Tim Elliot  02/01/15              shot         gun  53.0
# 1        4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2        5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3        8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4        9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
# ...    ...                 ...       ...               ...         ...   ...
# 2530  2822    Rodney E. Jacobs  28/07/17              shot         gun  31.0
# 2531  2813               TK TK  28/07/17              shot     vehicle   NaN
# 2532  2818  Dennis W. Robinson  29/07/17              shot         gun  48.0
# 2533  2817       Isaiah Tucker  31/07/17              shot     vehicle  28.0
# 2534  2815        Dwayne Jeune  31/07/17              shot       knife  32.0
#
# ...

# %%
age= kill.groupby("age").sum().index
age
# Out:
# Float64Index([ 6.0, 12.0, 13.0, 14.0, 15.0, 16.0, 17.0, 18.0, 19.0, 20.0, 21.0,
#               22.0, 23.0, 24.0, 25.0, 26.0, 27.0, 28.0, 29.0, 30.0, 31.0, 32.0,
#               33.0, 34.0, 35.0, 36.0, 37.0, 38.0, 39.0, 40.0, 41.0, 42.0, 43.0,
#               44.0, 45.0, 46.0, 47.0, 48.0, 49.0, 50.0, 51.0, 52.0, 53.0, 54.0,
#               55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0, 63.0, 64.0, 65.0,
#               66.0, 67.0, 68.0, 69.0, 70.0, 71.0, 72.0, 73.0, 74.0, 75.0, 76.0,
#               77.0, 79.0, 80.0, 82.0, 83.0, 86.0, 91.0],
#              dtype='float64', name='age')

# %%
age_cat= kill.groupby("age_cat").sum().index
age_cat
# Out:
# Index(['above25', 'below25'], dtype='object', name='age_cat')

# %%
kill["age_cat"].value_counts()
# Out:
# above25    1905
# below25     450
# Name: age_cat, dtype: int64

# %%
kill.groupby("age_cat").count()
# Out:
#            id  name  date  manner_of_death  armed   age  gender  race  city  \
# age_cat
# above25  1905  1905  1905             1905   1897  1905    1905  1779  1905
# below25   450   450   450              450    450   450     450   433   450
#
#          state  signs_of_mental_illness  threat_level  flee  body_camera
# age_cat
# above25   1905                     1905          1905  1861         1905
# below25    450                      450           450   438          450

# %%
age_cat = kill.groupby("age_cat").count().index   # tips.day.unique()
age_cat
# Out:
# Index(['above25', 'below25'], dtype='object', name='age_cat')

# %%
age_cat = list(kill.groupby("age")["age_cat"].count())
age_cat
# Out:
# [1,
#  1,
#  1,
#  1,
#  8,
#  16,
#  23,
#  54,
#  41,
#  41,
#  52,
#  57,
#  71,
#  83,
#  0,
#  72,
#  72,
#  73,
#  83,
#  74,
#  85,
#  75,
#  78,
#  74,
#  74,
#  91,
#  66,
#  63,
#  53,
#  46,
#  52,
#  39,
#  42,
#  32,
#  62,
#  41,
#  37,
#  35,
#  38,
#  47,
#  36,
#  31,
#  42,
#  29,
#  28,
#  28,
#  20,
#  18,
#  35,
#  16,
#  11,
#  13,
#  16,
#  11,
#  7,
#  8,
#  5,
#  6,
#  7,
#  5,
#  4,
#  3,
#  2,
#  2,
#  2,
#  5,
#  2,
#  1,
#  1,
#  2,
#  2,
#  2,
#  1]

# %%
# with matplotlib
fig, ax= plt.subplots(figsize =(12,7))

ax.bar(age_cat, age_cat)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17400/1477596243.py in <module>
#       2 fig, ax= plt.subplots(figsize =(12,7))
#       3
# ----> 4 ax.bar(age_cat, age_cat)
#       5 plt.show()
#
# ~\anaconda3\envs\my-env\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\envs\my-env\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2277
#    2278         if orientation == 'vertical':
# -> 2279             self._process_unit_info(
#    2280                 [("x", x), ("y", height)], kwargs, convert=False)
# ...

# %% [markdown]
# ## 4: Plot number of killed poeple by race

# %%
race =kill["race"].value_counts().head(7)
race
# Out:
# W    1201
# B     618
# H     423
# A      39
# N      31
# O      28
# Name: race, dtype: int64

# %%
# with matplotlib
fig, ax= plt.subplots()
ax.bar(kill, race)
fig.suptitle('Race of killed people')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17400/3228296755.py in <module>
#       1 # with matplotlib
#       2 fig, ax= plt.subplots()
# ----> 3 ax.bar(kill, race)
#       4 fig.suptitle('Race of killed people')
#
# ~\anaconda3\envs\my-env\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\envs\my-env\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2302                 yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
#    2303
# ...

# %% [markdown]
# ## 5: Killed People According to Races (Pie Chart)

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
race= kill.groupby("race").sum().index
race
# Out:
# Index(['A', 'B', 'H', 'N', 'O', 'W'], dtype='object', name='race')

# %%
kill["race"].value_counts().head(7)
# Out:
# W    1201
# B     618
# H     423
# A      39
# N      31
# O      28
# Name: race, dtype: int64

# %% [markdown]
# Problem: missing value on race column.

# %% [markdown]
# **INSTRUCTION-1: Drop the all raws that contain missing value (dropna)**

# %%
kill.dropna()
# Out:
#         id                   name      date   manner_of_death         armed  \
# 0        3             Tim Elliot  02/01/15              shot           gun
# 1        4       Lewis Lee Lembke  02/01/15              shot           gun
# 2        5     John Paul Quintero  03/01/15  shot and Tasered       unarmed
# 3        8        Matthew Hoffman  04/01/15              shot    toy weapon
# 4        9      Michael Rodriguez  04/01/15              shot      nail gun
# ...    ...                    ...       ...               ...           ...
# 2517  2802  Michael Joseph Harris  25/07/17              shot           gun
# 2519  2805            Aries Clark  25/07/17              shot  undetermined
# 2525  2820       Deltra Henderson  27/07/17              shot           gun
# 2533  2817          Isaiah Tucker  31/07/17              shot       vehicle
# 2534  2815           Dwayne Jeune  31/07/17              shot         knife
#
# ...

# %%
kill["age"].value_counts()
# Out:
# 25.0    103
# 36.0     91
# 31.0     85
# 24.0     83
# 29.0     83
#        ...
# 6.0       1
# 14.0      1
# 80.0      1
# 12.0      1
# 79.0      1
# Name: age, Length: 73, dtype: int64

# %% [markdown]
# **INSTRUCTION-2: Demonstrate Race Ratio of Killed People by a Pie Chart (You can use Matplotlib)**

# %%
df=kill["race"].value_counts().head(7)
df
# Out:
# W    1201
# B     618
# H     423
# A      39
# N      31
# O      28
# Name: race, dtype: int64

# %%
race= kill.groupby("race").sum().index
race
# Out:
# Index(['A', 'B', 'H', 'N', 'O', 'W'], dtype='object', name='race')

# %%
kills=list(kill.groupby('race')['name'].count())
kills
# Out:
# [39, 618, 423, 31, 28, 1201]

# %%
# matplotlib
activities = ['A', 'B', 'H','N','O','W']  
exp = [0.2,0.02,0.02,0.2,0.02,0.2] 
plt.pie( kills,labels=activities,
        textprops=dict(size=25,color='black'), 
        radius=3, 
        
        autopct='%2.2f%%', 
        explode=exp, 
        shadow=True, 
        startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x272f201ec70>,
# ...
#  [Text(-0.18317585639493586, 3.4952033711407955, 'A'),
#   Text(-2.670129926290504, 1.9730195581209704, 'B'),
#   Text(-2.403635480214914, -2.2901826298904684, 'H'),
#   Text(-0.6954848860291774, -3.4302041882816514, 'N'),
#   Text(-0.40018137863605746, -3.295793510551434, 'O'),
#   Text(3.496969144303012, -0.14562556023123263, 'W')],
#  [Text(-0.10467191793996333, 1.9972590692233114, '1.67%'),
#   Text(-1.4637459234484087, 1.0815950589699292, '26.41%'),
#   Text(-1.3176555945756454, -1.255461562168871, '18.08%'),
#   Text(-0.3974199348738155, -1.9601166790180862, '1.32%'),
#   Text(-0.21937653889085074, -1.8067301774709665, '1.20%'),
#   Text(1.9982680824588637, -0.08321460584641864, '51.32%')])
